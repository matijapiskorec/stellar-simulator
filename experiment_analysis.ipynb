# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in ./.venv/lib/python3.11/site-packages (from pandas) (1.25.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import re
import pandas as pd
from collections import defaultdict

def get_transaction_count(line):
    pattern = r"transactions = \{([^}]+)\}"
    match = re.search(pattern, line)
    if match:
        return set(re.findall(r"Transaction ([a-fA-F0-9]+)", match.group(1)))
    return set()

def get_timestamp(line):
    pattern = r"^\d+\.\d+"
    match = re.match(pattern, line)
    return float(match.group(0)) if match else None

def get_node_name(line):
    pattern = r"Node ([A-Z0-9]+)"
    match = re.search(pattern, line)
    return match.group(1) if match else None

def count_unique_mempool_transactions(file_path, node_number):
    unique_transactions = set()
    with open(file_path, 'r') as file:
        for line in file:
            if f"Node {node_number}" in line and "from mempool" in line:
                unique_transactions.update(re.findall(r"Transaction ([a-fA-F0-9]+)", line))
    return len(unique_transactions)


def process_log_lines(file_path):
    node_data = defaultdict(lambda: {
        "Timestamp of finalisation": None, 
        "Finalised transactions": set(),  
        "Externalize messages": []
    })
    
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    for line in lines:
        if 'appended SCPExternalize message to its storage and state' not in line:
            continue
        
        node_name = get_node_name(line)
        timestamp = get_timestamp(line)
        transactions = get_transaction_count(line)
        
        if node_name:
            if node_data[node_name]["Timestamp of finalisation"] is None:
                node_data[node_name]["Timestamp of finalisation"] = timestamp
            node_data[node_name]["Finalised transactions"].update(transactions)
            node_data[node_name]["Externalize messages"].append(line.strip())
    
    df = pd.DataFrame.from_dict(node_data, orient='index')
    df.index.name = "sequence number"
    df = df.reset_index()
    
    df["No. of finalised transactions"] = df["Finalised transactions"].apply(len)
    
    df["total_transactions"] = df["sequence number"].apply(lambda node: count_unique_mempool_transactions(file_path, node))
    
    df["no. of transactions not finalised"] = df["total_transactions"] - df["No. of finalised transactions"]
    
    return df

# %%
file_path = 'src/simulator_events_log.txt'

df = process_log_lines(file_path)
df_sorted = df.sort_values(by='Timestamp of finalisation', ascending=True)

# %% [markdown]
# ADD INTERLEDGER CHECKS

# %%
def calculate_inter_ledger_agreement_time(df):
    df = df.sort_values(by='Timestamp of finalisation')
    time_diffs = df['Timestamp of finalisation'].diff().dropna()
    
    return time_diffs.mean()

avg_time = calculate_inter_ledger_agreement_time(df_sorted)
print(f"Average Inter-Ledger Agreement Time: {avg_time}")
# Out:
# Average Inter-Ledger Agreement Time: 1.2787499999999998

# %%
final_experiment_df = df_sorted[[
    "sequence number",
    "Timestamp of finalisation",
    "No. of finalised transactions",
    "no. of transactions not finalised"
]]

display(final_experiment_df)
# Out:
#    sequence number  Timestamp of finalisation  No. of finalised transactions  no. of transactions not finalised
# 0         21                 8.0600                         12                               35
# 1         38                13.7200                          3                               45
# 2         18                14.2500                         16                               24
# 3         30                19.8900                          8                               39
# 4          9                20.2800                          3                               45
# 5         32                20.6300                          2                               51
# 6         56                21.2800                          3                               45
# 7         28                26.0200                          1                               50
# 8         25                29.4500                          6                               40
# 9         33                30.0400                          5                               43
# 10        48                30.4100                          5                               43
# 11        53                31.2400                          3                               45
# 12        52                34.3400                          2                               43
# 13        57                34.6000                          5                               39
# 14         0                34.8100                         13                               35
# 15        15                34.9700                          5                               40
# 16         2                35.3100                         14                               54
# 17        43                36.5900                          8                               45
# 18         5                39.1000                          4                               65
# 19        36                40.1500                          4                               38
# 20        44                41.6700                         10                               40
# 21        29                42.0100                         18                               29
# 22        17                42.1700                         12                               35
# 23        47                42.8300                         12                               39
# 24        49                43.3600                         12                               34
# 25         7                44.6100                         14                               36
# 26        27                46.9800                          7                               35
# 27        45                47.4500                         17                               34
# 28        13                47.7100                         23                               22
# 29        37                48.1100                         11                               38
# 30        41                48.4900                         15                               29
# 31        51                48.6300                         21                               25
# 32        24                49.3000                          5                               50
# 33        59                50.8500                         10                               40
# 34        22                53.1500                          6                               40
# 35        26                55.3800                         14                               28
# 36        50                58.9900                         15                               41
# 37         1                59.0900                         19                               47
# 38        16                59.9400                          2                               41
# 39         8                60.0600                          8                               44
# 40        34                60.4900                         16                               36
# 41         3                60.8700                          6                               62
# 42        23                61.0300                         12                               26
# 43        39                61.1600                         22                               21
# 44        20                62.8600                         19                               31
# 45        55                65.8000                          6                               41
# 46         6                67.9500                          1                               43
# 47        54                68.0000                         19                               26
# 48        14                69.4400                         17                               26

# %%
avg_difference = (final_experiment_df["no. of transactions not finalised"] - final_experiment_df["No. of finalised transactions"]).mean()

print(f"Average difference: {avg_difference}")
# Out:
# Average difference: 28.816326530612244

# %%
avg_finalised = final_experiment_df["No. of finalised transactions"].mean()
avg_total = (final_experiment_df["No. of finalised transactions"] + 
             final_experiment_df["no. of transactions not finalised"]).mean()

finalised_percentage = (avg_finalised / avg_total) * 100 if avg_total != 0 else 0

print(f"Percentage of finalised transactions vs total: {finalised_percentage:.2f}%")
# Out:
# Percentage of finalised transactions vs total: 20.51%

# %% [markdown]
# # ADD CHECKS FOR FIST EXTERNALIZE

# %%
import re
import pandas as pd
from collections import defaultdict

def get_transaction_count(line):
    pattern = r"transactions = \{([^}]+)\}"
    match = re.search(pattern, line)
    if match:
        return set(re.findall(r"Transaction ([a-fA-F0-9]+)", match.group(1)))
    return set()

def get_timestamp(line):
    pattern = r"^\d+\.\d+"
    match = re.match(pattern, line)
    return float(match.group(0)) if match else None

def get_node_name(line):
    pattern = r"Node ([A-Za-z0-9]+)"
    match = re.search(pattern, line)
    return match.group(1) if match else None

def count_unique_mempool_transactions(file_path, node_number):
    unique_transactions = set()
    with open(file_path, 'r') as file:
        for line in file:
            if f"Node {node_number}" in line and "from mempool" in line:
                unique_transactions.update(re.findall(r"Transaction ([a-fA-F0-9]+)", line))
    return len(unique_transactions)

def process_log_lines(file_path):
    """
    Extracts the first SCPExternalize message per node and stores its relevant details.
    Ensures that once a node is added, it is never updated again.
    """
    node_data = {}

    with open(file_path, 'r') as file:
        for line in file:
            # Only consider lines that contain relevant externalization messages
            if ("appended SCPExternalize message to its storage and state" not in line and
                "adopting externalized value for slot" not in line):
                continue
            
            node_name = get_node_name(line)
            timestamp = get_timestamp(line)
            transactions = get_transaction_count(line)

            if node_name and node_name not in node_data:
                # If the node has never been recorded before, store its first occurrence
                node_data[node_name] = {
                    "Timestamp of finalisation": timestamp,
                    "Finalised transactions": transactions,
                    "Externalize message": line.strip()
                }
    
    # Convert to DataFrame
    df = pd.DataFrame.from_dict(node_data, orient='index')
    df.index.name = "node name"
    df = df.reset_index()

    # Count the number of finalized transactions per node
    df["No. of finalised transactions"] = df["Finalised transactions"].apply(len)

    # Compute total transactions for each node from mempool logs
    df["total_transactions"] = df["node name"].apply(lambda node: count_unique_mempool_transactions(file_path, node))

    # Calculate number of transactions not finalized
    df["no. of transactions not finalised"] = df["total_transactions"] - df["No. of finalised transactions"]

    return df

# Example usage:
# file_path = 'path/to/your/simulator_events_log.txt'
# df = process_log_lines(file_path)
# print(df)

# %%
file_path = 'src/simulator_events_log.txt'

df = process_log_lines(file_path)
df_sorted = df.sort_values(by='Timestamp of finalisation', ascending=True)

pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000)  # Prevent line wrapping
pd.set_option('display.colheader_justify', 'center')  # Center column headers
pd.set_option('display.float_format', '{:.4f}'.format)  # Format float values


display(df_sorted)
# Out:
#    node name  Timestamp of finalisation               Finalised transactions                              Externalize message                  No. of finalised transactions  total_transactions  no. of transactions not finalised
# 0      21              8.0600                                                    {2228996}  8.06 - NODE - INFO - Node 21 appended SCPExter...                1                        47                         46
# 1      38             13.7200                                {d66ce25c, 2228996, 258e61a1}  13.72 - NODE - INFO - Node 38 appended SCPExte...                3                        48                         45
# 2      18             14.2500                                                    {2228996}  14.25 - NODE - INFO - Node 18 appended SCPExte...                1                        40                         39
# 3      30             19.8900                                          {2228996, 258e61a1}  19.89 - NODE - INFO - Node 30 appended SCPExte...                2                        47                         45
# 4       9             20.2800                                {347fff85, 2228996, 258e61a1}  20.28 - NODE - INFO - Node 9 appended SCPExter...                3                        48                         45
# 5      32             20.6300                                          {2228996, 258e61a1}  20.63 - NODE - INFO - Node 32 appended SCPExte...                2                        53                         51
# 6      56             21.2800                                {d66ce25c, 2228996, 258e61a1}  21.28 - NODE - INFO - Node 56 appended SCPExte...                3                        48                         45
# 7      28             26.0200                                                    {2228996}  26.02 - NODE - INFO - Node 28 appended SCPExte...                1                        51                         50
# 8      25             29.4500            {d66ce25c, cacc09f7, 2228996, 347fff85, 258e61...  29.45 - NODE - INFO - Node 25 appended SCPExte...                6                        46                         40
# 9      33             30.0400            {d66ce25c, 2228996, 347fff85, 258e61a1, 24139ce1}  30.04 - NODE - INFO - Node 33 appended SCPExte...                5                        48                         43
# 10     48             30.4100            {d66ce25c, cacc09f7, 2228996, 347fff85, 258e61a1}  30.41 - NODE - INFO - Node 48 appended SCPExte...                5                        48                         43
# 11     53             31.2400                               {347fff85, cacc09f7, 258e61a1}  31.24 - NODE - INFO - Node 53 appended SCPExte...                3                        48                         45
# 12     52             34.3400                                                    {2228996}  34.34 - NODE - INFO - Node 52 appended SCPExte...                1                        45                         44
# 13     57             34.6000            {d66ce25c, cacc09f7, 2228996, 347fff85, 258e61a1}  34.60 - NODE - INFO - Node 57 appended SCPExte...                5                        44                         39
# 14      0             34.8100                                          {2228996, 258e61a1}  34.81 - NODE - INFO - Node 0 appended SCPExter...                2                        48                         46
# 15     15             34.9700            {d66ce25c, cacc09f7, 2228996, 347fff85, 258e61a1}  34.97 - NODE - INFO - Node 15 appended SCPExte...                5                        45                         40
# 16      2             35.3100            {ed94cde, d66ce25c, cacc09f7, 2228996, 347fff8...  35.31 - NODE - INFO - Node 2 appended SCPExter...                9                        68                         59
# 17     43             36.5900            {d66ce25c, cacc09f7, 347fff85, 258e61a1, c6518...  36.59 - NODE - INFO - Node 43 appended SCPExte...                8                        53                         45
# 18      5             39.1000                                                    {2228996}  39.10 - NODE - INFO - Node 5 appended SCPExter...                1                        69                         68
# 19     36             40.1500                      {2228996, cacc09f7, 258e61a1, 347fff85}  40.15 - NODE - INFO - Node 36 appended SCPExte...                4                        42                         38
# 20     44             41.6700            {ed94cde, d66ce25c, cacc09f7, 9cdc16d0, 347fff...  41.67 - NODE - INFO - Node 44 appended SCPExte...               10                        50                         40
# 21     29             42.0100            {ed94cde, d66ce25c, cacc09f7, 347fff85, 258e61...  42.01 - NODE - INFO - Node 29 appended SCPExte...                6                        47                         41
# 22     17             42.1700            {d66ce25c, cacc09f7, 2228996, 347fff85, 258e61...  42.17 - NODE - INFO - Node 17 appended SCPExte...                6                        47                         41
# 23     47             42.8300            {ed94cde, d66ce25c, cacc09f7, 5bd0a3ab, ac0228...  42.83 - NODE - INFO - Node 47 appended SCPExte...               12                        51                         39
# 24     49             43.3600            {ed94cde, d66ce25c, cacc09f7, 9cdc16d0, 347fff...  43.36 - NODE - INFO - Node 49 appended SCPExte...               11                        46                         35
# 25      7             44.6100            {48a04c37, ed94cde, cacc09f7, 87459e6a, ac0228...  44.61 - NODE - INFO - Node 7 appended SCPExter...               11                        50                         39
# 26     27             46.9800            {d66ce25c, cacc09f7, 347fff85, 258e61a1, 24139...  46.98 - NODE - INFO - Node 27 appended SCPExte...                6                        42                         36
# 27     45             47.4500            {d66ce25c, cacc09f7, 2228996, 347fff85, 258e61...  47.45 - NODE - INFO - Node 45 appended SCPExte...                6                        51                         45
# 28     13             47.7100                                {d66ce25c, 2228996, 258e61a1}  47.71 - NODE - INFO - Node 13 appended SCPExte...                3                        45                         42
# 29     37             48.1100            {48a04c37, ed94cde, 5bd0a3ab, 87459e6a, cd52bb...  48.11 - NODE - INFO - Node 37 appended SCPExte...               11                        49                         38
# 30     41             48.4900            {48a04c37, ed94cde, d66ce25c, cacc09f7, 87459e...  48.49 - NODE - INFO - Node 41 appended SCPExte...               15                        44                         29
# 31     51             48.6300            {ed94cde, d66ce25c, cacc09f7, 2228996, 347fff8...  48.63 - NODE - INFO - Node 51 appended SCPExte...                9                        46                         37
# 32     24             49.3000            {d66ce25c, cacc09f7, 2228996, 347fff85, 258e61a1}  49.30 - NODE - INFO - Node 24 appended SCPExte...                5                        55                         50
# 33     59             50.8500            {ed94cde, 5bd0a3ab, 87459e6a, ac0228a2, 9cdc16...  50.85 - NODE - INFO - Node 59 appended SCPExte...               10                        50                         40
# 34     22             53.1500            {ed94cde, d66ce25c, cacc09f7, 347fff85, 258e61...  53.15 - NODE - INFO - Node 22 appended SCPExte...                6                        46                         40
# 35     26             55.3800                                          {2228996, 258e61a1}  55.38 - NODE - INFO - Node 26 appended SCPExte...                2                        42                         40
# 36     50             58.9900            {d66ce25c, cacc09f7, 347fff85, 258e61a1, c6518...  58.99 - NODE - INFO - Node 50 appended SCPExte...                6                        56                         50
# 37      1             59.0900            {c6518507, dafcc001, cacc09f7, 5bd0a3ab, 22289...  59.09 - NODE - INFO - Node 1 appended SCPExter...               19                        66                         47
# 38     16             59.9400                                          {2228996, 258e61a1}  59.94 - NODE - INFO - Node 16 appended SCPExte...                2                        43                         41
# 39      8             60.0600            {ed94cde, d66ce25c, cacc09f7, ac0228a2, 347fff...  60.06 - NODE - INFO - Node 8 appended SCPExter...                8                        52                         44
# 40     34             60.4900            {48a04c37, ed94cde, d66ce25c, cacc09f7, 87459e...  60.49 - NODE - INFO - Node 34 appended SCPExte...               16                        52                         36
# 41      3             60.8700            {ed94cde, d66ce25c, cacc09f7, 2228996, 258e61a...  60.87 - NODE - INFO - Node 3 appended SCPExter...                6                        68                         62
# 42     23             61.0300            {ed94cde, d66ce25c, cacc09f7, 2228996, ac0228a...  61.03 - NODE - INFO - Node 23 appended SCPExte...               12                        38                         26
# 43     39             61.1600                                {d66ce25c, 2228996, 258e61a1}  61.16 - NODE - INFO - Node 39 appended SCPExte...                3                        43                         40
# 44     20             62.8600            {cd52bb57, c6518507, dafcc001, cacc09f7, 5bd0a...  62.86 - NODE - INFO - Node 20 appended SCPExte...               19                        50                         31
# 45     55             65.8000            {d66ce25c, cacc09f7, 2228996, 347fff85, 258e61...  65.80 - NODE - INFO - Node 55 appended SCPExte...                6                        47                         41
# 46      6             67.9500                                                    {2228996}  67.95 - NODE - INFO - Node 6 appended SCPExter...                1                        44                         43
# 47     54             68.0000            {c6518507, dafcc001, cacc09f7, 5bd0a3ab, 22289...  68.00 - NODE - INFO - Node 54 appended SCPExte...               19                        45                         26
# 48     14             69.4400            {48a04c37, ed94cde, d66ce25c, cacc09f7, 1e8dd8...  69.44 - NODE - INFO - Node 14 appended SCPExte...               17                        43                         26

# %%
import pandas as pd

def check_exact_matches(df):
    # Convert 'Finalised transactions' to sets
    def convert_to_set(val):
        if isinstance(val, str):
            return eval(val)  # Convert string representation to set
        elif isinstance(val, set):
            return val  # If it's already a set, return it
        else:
            return set()  # In case of any unexpected format
    
    # Convert the 'Finalised transactions' column to sets
    df['Finalised transactions'] = df['Finalised transactions'].apply(convert_to_set)
    
    # Create a dictionary to store matches
    matches = {}
    
    # Iterate through each row and compare 'Finalised transactions' with every other row
    for i, row_i in df.iterrows():
        node_i = row_i["node name"]
        transactions_i = row_i["Finalised transactions"]
        
        for j, row_j in df.iterrows():
            if i < j:  # Only compare each pair once
                node_j = row_j["node name"]
                transactions_j = row_j["Finalised transactions"]
                
                # Check if the transactions are exactly the same (size and content)
                if len(transactions_i) == len(transactions_j) and transactions_i == transactions_j:
                    if node_i not in matches:
                        matches[node_i] = []
                    matches[node_i].append(node_j)
    
    return matches

# Assuming df_sorted is your DataFrame
matches = check_exact_matches(df_sorted)

# Print the matches
for node, matched_nodes in matches.items():
    print(f"Node {node} has the exact same transactions as:")
    for matched_node in matched_nodes:
        print(f"  - {matched_node}")
# Out:
# Node 21 has the exact same transactions as:
#   - 18
#   - 28
#   - 52
#   - 5
#   - 6
# Node 38 has the exact same transactions as:
#   - 56
#   - 13
#   - 39
# Node 18 has the exact same transactions as:
#   - 28
#   - 52
#   - 5
#   - 6
# Node 30 has the exact same transactions as:
#   - 32
#   - 0
#   - 26
#   - 16
# Node 32 has the exact same transactions as:
#   - 0
#   - 26
#   - 16
# Node 56 has the exact same transactions as:
#   - 13
#   - 39
# Node 28 has the exact same transactions as:
#   - 52
#   - 5
#   - 6
# Node 25 has the exact same transactions as:
#   - 17
#   - 45
#   - 55
# Node 48 has the exact same transactions as:
#   - 57
#   - 15
#   - 24
# Node 52 has the exact same transactions as:
#   - 5
#   - 6
# Node 57 has the exact same transactions as:
#   - 15
#   - 24
# Node 0 has the exact same transactions as:
#   - 26
#   - 16
# Node 15 has the exact same transactions as:
#   - 24
# Node 5 has the exact same transactions as:
#   - 6
# Node 29 has the exact same transactions as:
#   - 22
# Node 17 has the exact same transactions as:
#   - 45
#   - 55
# Node 45 has the exact same transactions as:
#   - 55
# Node 13 has the exact same transactions as:
#   - 39
# Node 26 has the exact same transactions as:
#   - 16

# %%
def compute_matching_transactions(df):
    matching_counts = {}

    # Compare the transactions of each node with the other nodes
    for i, row_i in df.iterrows():
        node_i = row_i["node name"]
        transactions_i = row_i["Finalised transactions"]
        
        matching_transactions = {}

        for j, row_j in df.iterrows():
            if i != j:  # Don't compare the node with itself
                node_j = row_j["node name"]
                transactions_j = row_j["Finalised transactions"]
                
                # Find common transactions between node_i and node_j
                common_transactions = transactions_i.intersection(transactions_j)
                matching_transactions[node_j] = len(common_transactions)

        matching_counts[node_i] = matching_transactions

    return matching_counts

# Get the matching transaction counts
matching_counts = compute_matching_transactions(df)

# Display the results
for node, matches in matching_counts.items():
    print(f"Matching transactions for node {node}:")
    for other_node, count in matches.items():
        print(f"  - {other_node}: {count} matching transactions")
# Out:
# Matching transactions for node 21:
#   - 38: 1 matching transactions
#   - 18: 1 matching transactions
#   - 30: 1 matching transactions
#   - 9: 1 matching transactions
#   - 32: 1 matching transactions
#   - 56: 1 matching transactions
#   - 28: 1 matching transactions
#   - 25: 1 matching transactions
#   - 33: 1 matching transactions
#   - 48: 1 matching transactions
#   - 53: 0 matching transactions
#   - 52: 1 matching transactions
#   - 57: 1 matching transactions
#   - 0: 1 matching transactions
#   - 15: 1 matching transactions
#   - 2: 1 matching transactions
#   - 43: 0 matching transactions
#   - 5: 1 matching transactions
#   - 36: 1 matching transactions
#   - 44: 0 matching transactions
#   - 29: 0 matching transactions
#   - 17: 1 matching transactions
#   - 47: 0 matching transactions
#   - 49: 0 matching transactions
#   - 7: 0 matching transactions
#   - 27: 0 matching transactions
#   - 45: 1 matching transactions
#   - 13: 1 matching transactions
#   - 37: 0 matching transactions
#   - 41: 1 matching transactions
#   - 51: 1 matching transactions
#   - 24: 1 matching transactions
#   - 59: 0 matching transactions
#   - 22: 0 matching transactions
#   - 26: 1 matching transactions
#   - 50: 0 matching transactions
#   - 1: 1 matching transactions
#   - 16: 1 matching transactions
#   - 8: 0 matching transactions
#   - 34: 1 matching transactions
#   - 3: 1 matching transactions
#   - 23: 1 matching transactions
#   - 39: 1 matching transactions
#   - 20: 1 matching transactions
#   - 55: 1 matching transactions
#   - 6: 1 matching transactions
#   - 54: 1 matching transactions
#   - 14: 1 matching transactions
# Matching transactions for node 38:
#   - 21: 1 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 2 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 3 matching transactions
#   - 33: 3 matching transactions
#   - 48: 3 matching transactions
#   - 53: 1 matching transactions
#   - 52: 1 matching transactions
#   - 57: 3 matching transactions
#   - 0: 2 matching transactions
#   - 15: 3 matching transactions
#   - 2: 3 matching transactions
#   - 43: 2 matching transactions
#   - 5: 1 matching transactions
#   - 36: 2 matching transactions
#   - 44: 2 matching transactions
#   - 29: 2 matching transactions
#   - 17: 3 matching transactions
#   - 47: 1 matching transactions
#   - 49: 2 matching transactions
#   - 7: 0 matching transactions
#   - 27: 2 matching transactions
#   - 45: 3 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 3 matching transactions
#   - 51: 3 matching transactions
#   - 24: 3 matching transactions
#   - 59: 0 matching transactions
#   - 22: 2 matching transactions
#   - 26: 2 matching transactions
#   - 50: 2 matching transactions
#   - 1: 3 matching transactions
#   - 16: 2 matching transactions
#   - 8: 2 matching transactions
#   - 34: 3 matching transactions
#   - 3: 3 matching transactions
#   - 23: 3 matching transactions
#   - 39: 3 matching transactions
#   - 20: 3 matching transactions
#   - 55: 3 matching transactions
#   - 6: 1 matching transactions
#   - 54: 3 matching transactions
#   - 14: 3 matching transactions
# Matching transactions for node 18:
#   - 21: 1 matching transactions
#   - 38: 1 matching transactions
#   - 30: 1 matching transactions
#   - 9: 1 matching transactions
#   - 32: 1 matching transactions
#   - 56: 1 matching transactions
#   - 28: 1 matching transactions
#   - 25: 1 matching transactions
#   - 33: 1 matching transactions
#   - 48: 1 matching transactions
#   - 53: 0 matching transactions
#   - 52: 1 matching transactions
#   - 57: 1 matching transactions
#   - 0: 1 matching transactions
#   - 15: 1 matching transactions
#   - 2: 1 matching transactions
#   - 43: 0 matching transactions
#   - 5: 1 matching transactions
#   - 36: 1 matching transactions
#   - 44: 0 matching transactions
#   - 29: 0 matching transactions
#   - 17: 1 matching transactions
#   - 47: 0 matching transactions
#   - 49: 0 matching transactions
#   - 7: 0 matching transactions
#   - 27: 0 matching transactions
#   - 45: 1 matching transactions
#   - 13: 1 matching transactions
#   - 37: 0 matching transactions
#   - 41: 1 matching transactions
#   - 51: 1 matching transactions
#   - 24: 1 matching transactions
#   - 59: 0 matching transactions
#   - 22: 0 matching transactions
#   - 26: 1 matching transactions
#   - 50: 0 matching transactions
#   - 1: 1 matching transactions
#   - 16: 1 matching transactions
#   - 8: 0 matching transactions
#   - 34: 1 matching transactions
#   - 3: 1 matching transactions
#   - 23: 1 matching transactions
#   - 39: 1 matching transactions
#   - 20: 1 matching transactions
#   - 55: 1 matching transactions
#   - 6: 1 matching transactions
#   - 54: 1 matching transactions
#   - 14: 1 matching transactions
# Matching transactions for node 30:
#   - 21: 1 matching transactions
#   - 38: 2 matching transactions
#   - 18: 1 matching transactions
#   - 9: 2 matching transactions
#   - 32: 2 matching transactions
#   - 56: 2 matching transactions
#   - 28: 1 matching transactions
#   - 25: 2 matching transactions
#   - 33: 2 matching transactions
#   - 48: 2 matching transactions
#   - 53: 1 matching transactions
#   - 52: 1 matching transactions
#   - 57: 2 matching transactions
#   - 0: 2 matching transactions
#   - 15: 2 matching transactions
#   - 2: 2 matching transactions
#   - 43: 1 matching transactions
#   - 5: 1 matching transactions
#   - 36: 2 matching transactions
#   - 44: 1 matching transactions
#   - 29: 1 matching transactions
#   - 17: 2 matching transactions
#   - 47: 0 matching transactions
#   - 49: 1 matching transactions
#   - 7: 0 matching transactions
#   - 27: 1 matching transactions
#   - 45: 2 matching transactions
#   - 13: 2 matching transactions
#   - 37: 0 matching transactions
#   - 41: 2 matching transactions
#   - 51: 2 matching transactions
#   - 24: 2 matching transactions
#   - 59: 0 matching transactions
#   - 22: 1 matching transactions
#   - 26: 2 matching transactions
#   - 50: 1 matching transactions
#   - 1: 2 matching transactions
#   - 16: 2 matching transactions
#   - 8: 1 matching transactions
#   - 34: 2 matching transactions
#   - 3: 2 matching transactions
#   - 23: 2 matching transactions
#   - 39: 2 matching transactions
#   - 20: 2 matching transactions
#   - 55: 2 matching transactions
#   - 6: 1 matching transactions
#   - 54: 2 matching transactions
#   - 14: 2 matching transactions
# Matching transactions for node 9:
#   - 21: 1 matching transactions
#   - 38: 2 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 32: 2 matching transactions
#   - 56: 2 matching transactions
#   - 28: 1 matching transactions
#   - 25: 3 matching transactions
#   - 33: 3 matching transactions
#   - 48: 3 matching transactions
#   - 53: 2 matching transactions
#   - 52: 1 matching transactions
#   - 57: 3 matching transactions
#   - 0: 2 matching transactions
#   - 15: 3 matching transactions
#   - 2: 3 matching transactions
#   - 43: 2 matching transactions
#   - 5: 1 matching transactions
#   - 36: 3 matching transactions
#   - 44: 2 matching transactions
#   - 29: 2 matching transactions
#   - 17: 3 matching transactions
#   - 47: 0 matching transactions
#   - 49: 2 matching transactions
#   - 7: 0 matching transactions
#   - 27: 2 matching transactions
#   - 45: 3 matching transactions
#   - 13: 2 matching transactions
#   - 37: 0 matching transactions
#   - 41: 3 matching transactions
#   - 51: 3 matching transactions
#   - 24: 3 matching transactions
#   - 59: 0 matching transactions
#   - 22: 2 matching transactions
#   - 26: 2 matching transactions
#   - 50: 2 matching transactions
#   - 1: 3 matching transactions
#   - 16: 2 matching transactions
#   - 8: 2 matching transactions
#   - 34: 3 matching transactions
#   - 3: 2 matching transactions
#   - 23: 3 matching transactions
#   - 39: 2 matching transactions
#   - 20: 3 matching transactions
#   - 55: 3 matching transactions
#   - 6: 1 matching transactions
#   - 54: 3 matching transactions
#   - 14: 3 matching transactions
# Matching transactions for node 32:
#   - 21: 1 matching transactions
#   - 38: 2 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 2 matching transactions
#   - 56: 2 matching transactions
#   - 28: 1 matching transactions
#   - 25: 2 matching transactions
#   - 33: 2 matching transactions
#   - 48: 2 matching transactions
#   - 53: 1 matching transactions
#   - 52: 1 matching transactions
#   - 57: 2 matching transactions
#   - 0: 2 matching transactions
#   - 15: 2 matching transactions
#   - 2: 2 matching transactions
#   - 43: 1 matching transactions
#   - 5: 1 matching transactions
#   - 36: 2 matching transactions
#   - 44: 1 matching transactions
#   - 29: 1 matching transactions
#   - 17: 2 matching transactions
#   - 47: 0 matching transactions
#   - 49: 1 matching transactions
#   - 7: 0 matching transactions
#   - 27: 1 matching transactions
#   - 45: 2 matching transactions
#   - 13: 2 matching transactions
#   - 37: 0 matching transactions
#   - 41: 2 matching transactions
#   - 51: 2 matching transactions
#   - 24: 2 matching transactions
#   - 59: 0 matching transactions
#   - 22: 1 matching transactions
#   - 26: 2 matching transactions
#   - 50: 1 matching transactions
#   - 1: 2 matching transactions
#   - 16: 2 matching transactions
#   - 8: 1 matching transactions
#   - 34: 2 matching transactions
#   - 3: 2 matching transactions
#   - 23: 2 matching transactions
#   - 39: 2 matching transactions
#   - 20: 2 matching transactions
#   - 55: 2 matching transactions
#   - 6: 1 matching transactions
#   - 54: 2 matching transactions
#   - 14: 2 matching transactions
# Matching transactions for node 56:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 2 matching transactions
#   - 32: 2 matching transactions
#   - 28: 1 matching transactions
#   - 25: 3 matching transactions
#   - 33: 3 matching transactions
#   - 48: 3 matching transactions
#   - 53: 1 matching transactions
#   - 52: 1 matching transactions
#   - 57: 3 matching transactions
#   - 0: 2 matching transactions
#   - 15: 3 matching transactions
#   - 2: 3 matching transactions
#   - 43: 2 matching transactions
#   - 5: 1 matching transactions
#   - 36: 2 matching transactions
#   - 44: 2 matching transactions
#   - 29: 2 matching transactions
#   - 17: 3 matching transactions
#   - 47: 1 matching transactions
#   - 49: 2 matching transactions
#   - 7: 0 matching transactions
#   - 27: 2 matching transactions
#   - 45: 3 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 3 matching transactions
#   - 51: 3 matching transactions
#   - 24: 3 matching transactions
#   - 59: 0 matching transactions
#   - 22: 2 matching transactions
#   - 26: 2 matching transactions
#   - 50: 2 matching transactions
#   - 1: 3 matching transactions
#   - 16: 2 matching transactions
#   - 8: 2 matching transactions
#   - 34: 3 matching transactions
#   - 3: 3 matching transactions
#   - 23: 3 matching transactions
#   - 39: 3 matching transactions
#   - 20: 3 matching transactions
#   - 55: 3 matching transactions
#   - 6: 1 matching transactions
#   - 54: 3 matching transactions
#   - 14: 3 matching transactions
# Matching transactions for node 28:
#   - 21: 1 matching transactions
#   - 38: 1 matching transactions
#   - 18: 1 matching transactions
#   - 30: 1 matching transactions
#   - 9: 1 matching transactions
#   - 32: 1 matching transactions
#   - 56: 1 matching transactions
#   - 25: 1 matching transactions
#   - 33: 1 matching transactions
#   - 48: 1 matching transactions
#   - 53: 0 matching transactions
#   - 52: 1 matching transactions
#   - 57: 1 matching transactions
#   - 0: 1 matching transactions
#   - 15: 1 matching transactions
#   - 2: 1 matching transactions
#   - 43: 0 matching transactions
#   - 5: 1 matching transactions
#   - 36: 1 matching transactions
#   - 44: 0 matching transactions
#   - 29: 0 matching transactions
#   - 17: 1 matching transactions
#   - 47: 0 matching transactions
#   - 49: 0 matching transactions
#   - 7: 0 matching transactions
#   - 27: 0 matching transactions
#   - 45: 1 matching transactions
#   - 13: 1 matching transactions
#   - 37: 0 matching transactions
#   - 41: 1 matching transactions
#   - 51: 1 matching transactions
#   - 24: 1 matching transactions
#   - 59: 0 matching transactions
#   - 22: 0 matching transactions
#   - 26: 1 matching transactions
#   - 50: 0 matching transactions
#   - 1: 1 matching transactions
#   - 16: 1 matching transactions
#   - 8: 0 matching transactions
#   - 34: 1 matching transactions
#   - 3: 1 matching transactions
#   - 23: 1 matching transactions
#   - 39: 1 matching transactions
#   - 20: 1 matching transactions
#   - 55: 1 matching transactions
#   - 6: 1 matching transactions
#   - 54: 1 matching transactions
#   - 14: 1 matching transactions
# Matching transactions for node 25:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 6 matching transactions
#   - 43: 5 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 5 matching transactions
#   - 29: 5 matching transactions
#   - 17: 6 matching transactions
#   - 47: 3 matching transactions
#   - 49: 5 matching transactions
#   - 7: 2 matching transactions
#   - 27: 5 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 6 matching transactions
#   - 51: 6 matching transactions
#   - 24: 5 matching transactions
#   - 59: 0 matching transactions
#   - 22: 5 matching transactions
#   - 26: 2 matching transactions
#   - 50: 4 matching transactions
#   - 1: 6 matching transactions
#   - 16: 2 matching transactions
#   - 8: 5 matching transactions
#   - 34: 6 matching transactions
#   - 3: 5 matching transactions
#   - 23: 6 matching transactions
#   - 39: 3 matching transactions
#   - 20: 6 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 6 matching transactions
#   - 14: 6 matching transactions
# Matching transactions for node 33:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 5 matching transactions
#   - 48: 4 matching transactions
#   - 53: 2 matching transactions
#   - 52: 1 matching transactions
#   - 57: 4 matching transactions
#   - 0: 2 matching transactions
#   - 15: 4 matching transactions
#   - 2: 5 matching transactions
#   - 43: 4 matching transactions
#   - 5: 1 matching transactions
#   - 36: 3 matching transactions
#   - 44: 4 matching transactions
#   - 29: 4 matching transactions
#   - 17: 5 matching transactions
#   - 47: 2 matching transactions
#   - 49: 4 matching transactions
#   - 7: 1 matching transactions
#   - 27: 4 matching transactions
#   - 45: 5 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 5 matching transactions
#   - 51: 5 matching transactions
#   - 24: 4 matching transactions
#   - 59: 0 matching transactions
#   - 22: 4 matching transactions
#   - 26: 2 matching transactions
#   - 50: 3 matching transactions
#   - 1: 5 matching transactions
#   - 16: 2 matching transactions
#   - 8: 4 matching transactions
#   - 34: 5 matching transactions
#   - 3: 4 matching transactions
#   - 23: 5 matching transactions
#   - 39: 3 matching transactions
#   - 20: 5 matching transactions
#   - 55: 5 matching transactions
#   - 6: 1 matching transactions
#   - 54: 5 matching transactions
#   - 14: 5 matching transactions
# Matching transactions for node 48:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 5 matching transactions
#   - 43: 4 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 4 matching transactions
#   - 29: 4 matching transactions
#   - 17: 5 matching transactions
#   - 47: 2 matching transactions
#   - 49: 4 matching transactions
#   - 7: 1 matching transactions
#   - 27: 4 matching transactions
#   - 45: 5 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 5 matching transactions
#   - 51: 5 matching transactions
#   - 24: 5 matching transactions
#   - 59: 0 matching transactions
#   - 22: 4 matching transactions
#   - 26: 2 matching transactions
#   - 50: 4 matching transactions
#   - 1: 5 matching transactions
#   - 16: 2 matching transactions
#   - 8: 4 matching transactions
#   - 34: 5 matching transactions
#   - 3: 4 matching transactions
#   - 23: 5 matching transactions
#   - 39: 3 matching transactions
#   - 20: 5 matching transactions
#   - 55: 5 matching transactions
#   - 6: 1 matching transactions
#   - 54: 5 matching transactions
#   - 14: 5 matching transactions
# Matching transactions for node 53:
#   - 21: 0 matching transactions
#   - 38: 1 matching transactions
#   - 18: 0 matching transactions
#   - 30: 1 matching transactions
#   - 9: 2 matching transactions
#   - 32: 1 matching transactions
#   - 56: 1 matching transactions
#   - 28: 0 matching transactions
#   - 25: 3 matching transactions
#   - 33: 2 matching transactions
#   - 48: 3 matching transactions
#   - 52: 0 matching transactions
#   - 57: 3 matching transactions
#   - 0: 1 matching transactions
#   - 15: 3 matching transactions
#   - 2: 3 matching transactions
#   - 43: 3 matching transactions
#   - 5: 0 matching transactions
#   - 36: 3 matching transactions
#   - 44: 3 matching transactions
#   - 29: 3 matching transactions
#   - 17: 3 matching transactions
#   - 47: 1 matching transactions
#   - 49: 3 matching transactions
#   - 7: 1 matching transactions
#   - 27: 3 matching transactions
#   - 45: 3 matching transactions
#   - 13: 1 matching transactions
#   - 37: 0 matching transactions
#   - 41: 3 matching transactions
#   - 51: 3 matching transactions
#   - 24: 3 matching transactions
#   - 59: 0 matching transactions
#   - 22: 3 matching transactions
#   - 26: 1 matching transactions
#   - 50: 3 matching transactions
#   - 1: 3 matching transactions
#   - 16: 1 matching transactions
#   - 8: 3 matching transactions
#   - 34: 3 matching transactions
#   - 3: 2 matching transactions
#   - 23: 3 matching transactions
#   - 39: 1 matching transactions
#   - 20: 3 matching transactions
#   - 55: 3 matching transactions
#   - 6: 0 matching transactions
#   - 54: 3 matching transactions
#   - 14: 3 matching transactions
# Matching transactions for node 52:
#   - 21: 1 matching transactions
#   - 38: 1 matching transactions
#   - 18: 1 matching transactions
#   - 30: 1 matching transactions
#   - 9: 1 matching transactions
#   - 32: 1 matching transactions
#   - 56: 1 matching transactions
#   - 28: 1 matching transactions
#   - 25: 1 matching transactions
#   - 33: 1 matching transactions
#   - 48: 1 matching transactions
#   - 53: 0 matching transactions
#   - 57: 1 matching transactions
#   - 0: 1 matching transactions
#   - 15: 1 matching transactions
#   - 2: 1 matching transactions
#   - 43: 0 matching transactions
#   - 5: 1 matching transactions
#   - 36: 1 matching transactions
#   - 44: 0 matching transactions
#   - 29: 0 matching transactions
#   - 17: 1 matching transactions
#   - 47: 0 matching transactions
#   - 49: 0 matching transactions
#   - 7: 0 matching transactions
#   - 27: 0 matching transactions
#   - 45: 1 matching transactions
#   - 13: 1 matching transactions
#   - 37: 0 matching transactions
#   - 41: 1 matching transactions
#   - 51: 1 matching transactions
#   - 24: 1 matching transactions
#   - 59: 0 matching transactions
#   - 22: 0 matching transactions
#   - 26: 1 matching transactions
#   - 50: 0 matching transactions
#   - 1: 1 matching transactions
#   - 16: 1 matching transactions
#   - 8: 0 matching transactions
#   - 34: 1 matching transactions
#   - 3: 1 matching transactions
#   - 23: 1 matching transactions
#   - 39: 1 matching transactions
#   - 20: 1 matching transactions
#   - 55: 1 matching transactions
#   - 6: 1 matching transactions
#   - 54: 1 matching transactions
#   - 14: 1 matching transactions
# Matching transactions for node 57:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 5 matching transactions
#   - 43: 4 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 4 matching transactions
#   - 29: 4 matching transactions
#   - 17: 5 matching transactions
#   - 47: 2 matching transactions
#   - 49: 4 matching transactions
#   - 7: 1 matching transactions
#   - 27: 4 matching transactions
#   - 45: 5 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 5 matching transactions
#   - 51: 5 matching transactions
#   - 24: 5 matching transactions
#   - 59: 0 matching transactions
#   - 22: 4 matching transactions
#   - 26: 2 matching transactions
#   - 50: 4 matching transactions
#   - 1: 5 matching transactions
#   - 16: 2 matching transactions
#   - 8: 4 matching transactions
#   - 34: 5 matching transactions
#   - 3: 4 matching transactions
#   - 23: 5 matching transactions
#   - 39: 3 matching transactions
#   - 20: 5 matching transactions
#   - 55: 5 matching transactions
#   - 6: 1 matching transactions
#   - 54: 5 matching transactions
#   - 14: 5 matching transactions
# Matching transactions for node 0:
#   - 21: 1 matching transactions
#   - 38: 2 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 2 matching transactions
#   - 32: 2 matching transactions
#   - 56: 2 matching transactions
#   - 28: 1 matching transactions
#   - 25: 2 matching transactions
#   - 33: 2 matching transactions
#   - 48: 2 matching transactions
#   - 53: 1 matching transactions
#   - 52: 1 matching transactions
#   - 57: 2 matching transactions
#   - 15: 2 matching transactions
#   - 2: 2 matching transactions
#   - 43: 1 matching transactions
#   - 5: 1 matching transactions
#   - 36: 2 matching transactions
#   - 44: 1 matching transactions
#   - 29: 1 matching transactions
#   - 17: 2 matching transactions
#   - 47: 0 matching transactions
#   - 49: 1 matching transactions
#   - 7: 0 matching transactions
#   - 27: 1 matching transactions
#   - 45: 2 matching transactions
#   - 13: 2 matching transactions
#   - 37: 0 matching transactions
#   - 41: 2 matching transactions
#   - 51: 2 matching transactions
#   - 24: 2 matching transactions
#   - 59: 0 matching transactions
#   - 22: 1 matching transactions
#   - 26: 2 matching transactions
#   - 50: 1 matching transactions
#   - 1: 2 matching transactions
#   - 16: 2 matching transactions
#   - 8: 1 matching transactions
#   - 34: 2 matching transactions
#   - 3: 2 matching transactions
#   - 23: 2 matching transactions
#   - 39: 2 matching transactions
#   - 20: 2 matching transactions
#   - 55: 2 matching transactions
#   - 6: 1 matching transactions
#   - 54: 2 matching transactions
#   - 14: 2 matching transactions
# Matching transactions for node 15:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 2: 5 matching transactions
#   - 43: 4 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 4 matching transactions
#   - 29: 4 matching transactions
#   - 17: 5 matching transactions
#   - 47: 2 matching transactions
#   - 49: 4 matching transactions
#   - 7: 1 matching transactions
#   - 27: 4 matching transactions
#   - 45: 5 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 5 matching transactions
#   - 51: 5 matching transactions
#   - 24: 5 matching transactions
#   - 59: 0 matching transactions
#   - 22: 4 matching transactions
#   - 26: 2 matching transactions
#   - 50: 4 matching transactions
#   - 1: 5 matching transactions
#   - 16: 2 matching transactions
#   - 8: 4 matching transactions
#   - 34: 5 matching transactions
#   - 3: 4 matching transactions
#   - 23: 5 matching transactions
#   - 39: 3 matching transactions
#   - 20: 5 matching transactions
#   - 55: 5 matching transactions
#   - 6: 1 matching transactions
#   - 54: 5 matching transactions
#   - 14: 5 matching transactions
# Matching transactions for node 2:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 43: 7 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 8 matching transactions
#   - 29: 6 matching transactions
#   - 17: 6 matching transactions
#   - 47: 6 matching transactions
#   - 49: 8 matching transactions
#   - 7: 5 matching transactions
#   - 27: 6 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 3 matching transactions
#   - 41: 9 matching transactions
#   - 51: 8 matching transactions
#   - 24: 5 matching transactions
#   - 59: 3 matching transactions
#   - 22: 6 matching transactions
#   - 26: 2 matching transactions
#   - 50: 5 matching transactions
#   - 1: 9 matching transactions
#   - 16: 2 matching transactions
#   - 8: 7 matching transactions
#   - 34: 9 matching transactions
#   - 3: 6 matching transactions
#   - 23: 9 matching transactions
#   - 39: 3 matching transactions
#   - 20: 9 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 9 matching transactions
#   - 14: 9 matching transactions
# Matching transactions for node 43:
#   - 21: 0 matching transactions
#   - 38: 2 matching transactions
#   - 18: 0 matching transactions
#   - 30: 1 matching transactions
#   - 9: 2 matching transactions
#   - 32: 1 matching transactions
#   - 56: 2 matching transactions
#   - 28: 0 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 4 matching transactions
#   - 53: 3 matching transactions
#   - 52: 0 matching transactions
#   - 57: 4 matching transactions
#   - 0: 1 matching transactions
#   - 15: 4 matching transactions
#   - 2: 7 matching transactions
#   - 5: 0 matching transactions
#   - 36: 3 matching transactions
#   - 44: 8 matching transactions
#   - 29: 5 matching transactions
#   - 17: 5 matching transactions
#   - 47: 6 matching transactions
#   - 49: 8 matching transactions
#   - 7: 5 matching transactions
#   - 27: 6 matching transactions
#   - 45: 5 matching transactions
#   - 13: 2 matching transactions
#   - 37: 3 matching transactions
#   - 41: 8 matching transactions
#   - 51: 7 matching transactions
#   - 24: 4 matching transactions
#   - 59: 3 matching transactions
#   - 22: 5 matching transactions
#   - 26: 1 matching transactions
#   - 50: 6 matching transactions
#   - 1: 8 matching transactions
#   - 16: 1 matching transactions
#   - 8: 6 matching transactions
#   - 34: 8 matching transactions
#   - 3: 4 matching transactions
#   - 23: 8 matching transactions
#   - 39: 2 matching transactions
#   - 20: 8 matching transactions
#   - 55: 5 matching transactions
#   - 6: 0 matching transactions
#   - 54: 8 matching transactions
#   - 14: 8 matching transactions
# Matching transactions for node 5:
#   - 21: 1 matching transactions
#   - 38: 1 matching transactions
#   - 18: 1 matching transactions
#   - 30: 1 matching transactions
#   - 9: 1 matching transactions
#   - 32: 1 matching transactions
#   - 56: 1 matching transactions
#   - 28: 1 matching transactions
#   - 25: 1 matching transactions
#   - 33: 1 matching transactions
#   - 48: 1 matching transactions
#   - 53: 0 matching transactions
#   - 52: 1 matching transactions
#   - 57: 1 matching transactions
#   - 0: 1 matching transactions
#   - 15: 1 matching transactions
#   - 2: 1 matching transactions
#   - 43: 0 matching transactions
#   - 36: 1 matching transactions
#   - 44: 0 matching transactions
#   - 29: 0 matching transactions
#   - 17: 1 matching transactions
#   - 47: 0 matching transactions
#   - 49: 0 matching transactions
#   - 7: 0 matching transactions
#   - 27: 0 matching transactions
#   - 45: 1 matching transactions
#   - 13: 1 matching transactions
#   - 37: 0 matching transactions
#   - 41: 1 matching transactions
#   - 51: 1 matching transactions
#   - 24: 1 matching transactions
#   - 59: 0 matching transactions
#   - 22: 0 matching transactions
#   - 26: 1 matching transactions
#   - 50: 0 matching transactions
#   - 1: 1 matching transactions
#   - 16: 1 matching transactions
#   - 8: 0 matching transactions
#   - 34: 1 matching transactions
#   - 3: 1 matching transactions
#   - 23: 1 matching transactions
#   - 39: 1 matching transactions
#   - 20: 1 matching transactions
#   - 55: 1 matching transactions
#   - 6: 1 matching transactions
#   - 54: 1 matching transactions
#   - 14: 1 matching transactions
# Matching transactions for node 36:
#   - 21: 1 matching transactions
#   - 38: 2 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 2 matching transactions
#   - 28: 1 matching transactions
#   - 25: 4 matching transactions
#   - 33: 3 matching transactions
#   - 48: 4 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 4 matching transactions
#   - 0: 2 matching transactions
#   - 15: 4 matching transactions
#   - 2: 4 matching transactions
#   - 43: 3 matching transactions
#   - 5: 1 matching transactions
#   - 44: 3 matching transactions
#   - 29: 3 matching transactions
#   - 17: 4 matching transactions
#   - 47: 1 matching transactions
#   - 49: 3 matching transactions
#   - 7: 1 matching transactions
#   - 27: 3 matching transactions
#   - 45: 4 matching transactions
#   - 13: 2 matching transactions
#   - 37: 0 matching transactions
#   - 41: 4 matching transactions
#   - 51: 4 matching transactions
#   - 24: 4 matching transactions
#   - 59: 0 matching transactions
#   - 22: 3 matching transactions
#   - 26: 2 matching transactions
#   - 50: 3 matching transactions
#   - 1: 4 matching transactions
#   - 16: 2 matching transactions
#   - 8: 3 matching transactions
#   - 34: 4 matching transactions
#   - 3: 3 matching transactions
#   - 23: 4 matching transactions
#   - 39: 2 matching transactions
#   - 20: 4 matching transactions
#   - 55: 4 matching transactions
#   - 6: 1 matching transactions
#   - 54: 4 matching transactions
#   - 14: 4 matching transactions
# Matching transactions for node 44:
#   - 21: 0 matching transactions
#   - 38: 2 matching transactions
#   - 18: 0 matching transactions
#   - 30: 1 matching transactions
#   - 9: 2 matching transactions
#   - 32: 1 matching transactions
#   - 56: 2 matching transactions
#   - 28: 0 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 4 matching transactions
#   - 53: 3 matching transactions
#   - 52: 0 matching transactions
#   - 57: 4 matching transactions
#   - 0: 1 matching transactions
#   - 15: 4 matching transactions
#   - 2: 8 matching transactions
#   - 43: 8 matching transactions
#   - 5: 0 matching transactions
#   - 36: 3 matching transactions
#   - 29: 6 matching transactions
#   - 17: 5 matching transactions
#   - 47: 8 matching transactions
#   - 49: 10 matching transactions
#   - 7: 7 matching transactions
#   - 27: 6 matching transactions
#   - 45: 5 matching transactions
#   - 13: 2 matching transactions
#   - 37: 5 matching transactions
#   - 41: 10 matching transactions
#   - 51: 8 matching transactions
#   - 24: 4 matching transactions
#   - 59: 5 matching transactions
#   - 22: 6 matching transactions
#   - 26: 1 matching transactions
#   - 50: 6 matching transactions
#   - 1: 10 matching transactions
#   - 16: 1 matching transactions
#   - 8: 7 matching transactions
#   - 34: 10 matching transactions
#   - 3: 5 matching transactions
#   - 23: 10 matching transactions
#   - 39: 2 matching transactions
#   - 20: 10 matching transactions
#   - 55: 5 matching transactions
#   - 6: 0 matching transactions
#   - 54: 10 matching transactions
#   - 14: 10 matching transactions
# Matching transactions for node 29:
#   - 21: 0 matching transactions
#   - 38: 2 matching transactions
#   - 18: 0 matching transactions
#   - 30: 1 matching transactions
#   - 9: 2 matching transactions
#   - 32: 1 matching transactions
#   - 56: 2 matching transactions
#   - 28: 0 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 4 matching transactions
#   - 53: 3 matching transactions
#   - 52: 0 matching transactions
#   - 57: 4 matching transactions
#   - 0: 1 matching transactions
#   - 15: 4 matching transactions
#   - 2: 6 matching transactions
#   - 43: 5 matching transactions
#   - 5: 0 matching transactions
#   - 36: 3 matching transactions
#   - 44: 6 matching transactions
#   - 17: 5 matching transactions
#   - 47: 4 matching transactions
#   - 49: 6 matching transactions
#   - 7: 3 matching transactions
#   - 27: 5 matching transactions
#   - 45: 5 matching transactions
#   - 13: 2 matching transactions
#   - 37: 1 matching transactions
#   - 41: 6 matching transactions
#   - 51: 6 matching transactions
#   - 24: 4 matching transactions
#   - 59: 1 matching transactions
#   - 22: 6 matching transactions
#   - 26: 1 matching transactions
#   - 50: 4 matching transactions
#   - 1: 6 matching transactions
#   - 16: 1 matching transactions
#   - 8: 6 matching transactions
#   - 34: 6 matching transactions
#   - 3: 5 matching transactions
#   - 23: 6 matching transactions
#   - 39: 2 matching transactions
#   - 20: 6 matching transactions
#   - 55: 5 matching transactions
#   - 6: 0 matching transactions
#   - 54: 6 matching transactions
#   - 14: 6 matching transactions
# Matching transactions for node 17:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 6 matching transactions
#   - 43: 5 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 5 matching transactions
#   - 29: 5 matching transactions
#   - 47: 3 matching transactions
#   - 49: 5 matching transactions
#   - 7: 2 matching transactions
#   - 27: 5 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 6 matching transactions
#   - 51: 6 matching transactions
#   - 24: 5 matching transactions
#   - 59: 0 matching transactions
#   - 22: 5 matching transactions
#   - 26: 2 matching transactions
#   - 50: 4 matching transactions
#   - 1: 6 matching transactions
#   - 16: 2 matching transactions
#   - 8: 5 matching transactions
#   - 34: 6 matching transactions
#   - 3: 5 matching transactions
#   - 23: 6 matching transactions
#   - 39: 3 matching transactions
#   - 20: 6 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 6 matching transactions
#   - 14: 6 matching transactions
# Matching transactions for node 47:
#   - 21: 0 matching transactions
#   - 38: 1 matching transactions
#   - 18: 0 matching transactions
#   - 30: 0 matching transactions
#   - 9: 0 matching transactions
#   - 32: 0 matching transactions
#   - 56: 1 matching transactions
#   - 28: 0 matching transactions
#   - 25: 3 matching transactions
#   - 33: 2 matching transactions
#   - 48: 2 matching transactions
#   - 53: 1 matching transactions
#   - 52: 0 matching transactions
#   - 57: 2 matching transactions
#   - 0: 0 matching transactions
#   - 15: 2 matching transactions
#   - 2: 6 matching transactions
#   - 43: 6 matching transactions
#   - 5: 0 matching transactions
#   - 36: 1 matching transactions
#   - 44: 8 matching transactions
#   - 29: 4 matching transactions
#   - 17: 3 matching transactions
#   - 49: 9 matching transactions
#   - 7: 9 matching transactions
#   - 27: 4 matching transactions
#   - 45: 3 matching transactions
#   - 13: 1 matching transactions
#   - 37: 8 matching transactions
#   - 41: 10 matching transactions
#   - 51: 6 matching transactions
#   - 24: 2 matching transactions
#   - 59: 9 matching transactions
#   - 22: 4 matching transactions
#   - 26: 0 matching transactions
#   - 50: 4 matching transactions
#   - 1: 11 matching transactions
#   - 16: 0 matching transactions
#   - 8: 6 matching transactions
#   - 34: 11 matching transactions
#   - 3: 4 matching transactions
#   - 23: 9 matching transactions
#   - 39: 1 matching transactions
#   - 20: 12 matching transactions
#   - 55: 3 matching transactions
#   - 6: 0 matching transactions
#   - 54: 12 matching transactions
#   - 14: 11 matching transactions
# Matching transactions for node 49:
#   - 21: 0 matching transactions
#   - 38: 2 matching transactions
#   - 18: 0 matching transactions
#   - 30: 1 matching transactions
#   - 9: 2 matching transactions
#   - 32: 1 matching transactions
#   - 56: 2 matching transactions
#   - 28: 0 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 4 matching transactions
#   - 53: 3 matching transactions
#   - 52: 0 matching transactions
#   - 57: 4 matching transactions
#   - 0: 1 matching transactions
#   - 15: 4 matching transactions
#   - 2: 8 matching transactions
#   - 43: 8 matching transactions
#   - 5: 0 matching transactions
#   - 36: 3 matching transactions
#   - 44: 10 matching transactions
#   - 29: 6 matching transactions
#   - 17: 5 matching transactions
#   - 47: 9 matching transactions
#   - 7: 7 matching transactions
#   - 27: 6 matching transactions
#   - 45: 5 matching transactions
#   - 13: 2 matching transactions
#   - 37: 5 matching transactions
#   - 41: 11 matching transactions
#   - 51: 8 matching transactions
#   - 24: 4 matching transactions
#   - 59: 6 matching transactions
#   - 22: 6 matching transactions
#   - 26: 1 matching transactions
#   - 50: 6 matching transactions
#   - 1: 11 matching transactions
#   - 16: 1 matching transactions
#   - 8: 7 matching transactions
#   - 34: 11 matching transactions
#   - 3: 5 matching transactions
#   - 23: 10 matching transactions
#   - 39: 2 matching transactions
#   - 20: 11 matching transactions
#   - 55: 5 matching transactions
#   - 6: 0 matching transactions
#   - 54: 11 matching transactions
#   - 14: 11 matching transactions
# Matching transactions for node 7:
#   - 21: 0 matching transactions
#   - 38: 0 matching transactions
#   - 18: 0 matching transactions
#   - 30: 0 matching transactions
#   - 9: 0 matching transactions
#   - 32: 0 matching transactions
#   - 56: 0 matching transactions
#   - 28: 0 matching transactions
#   - 25: 2 matching transactions
#   - 33: 1 matching transactions
#   - 48: 1 matching transactions
#   - 53: 1 matching transactions
#   - 52: 0 matching transactions
#   - 57: 1 matching transactions
#   - 0: 0 matching transactions
#   - 15: 1 matching transactions
#   - 2: 5 matching transactions
#   - 43: 5 matching transactions
#   - 5: 0 matching transactions
#   - 36: 1 matching transactions
#   - 44: 7 matching transactions
#   - 29: 3 matching transactions
#   - 17: 2 matching transactions
#   - 47: 9 matching transactions
#   - 49: 7 matching transactions
#   - 27: 3 matching transactions
#   - 45: 2 matching transactions
#   - 13: 0 matching transactions
#   - 37: 9 matching transactions
#   - 41: 10 matching transactions
#   - 51: 5 matching transactions
#   - 24: 1 matching transactions
#   - 59: 8 matching transactions
#   - 22: 3 matching transactions
#   - 26: 0 matching transactions
#   - 50: 3 matching transactions
#   - 1: 10 matching transactions
#   - 16: 0 matching transactions
#   - 8: 5 matching transactions
#   - 34: 11 matching transactions
#   - 3: 3 matching transactions
#   - 23: 8 matching transactions
#   - 39: 0 matching transactions
#   - 20: 10 matching transactions
#   - 55: 2 matching transactions
#   - 6: 0 matching transactions
#   - 54: 11 matching transactions
#   - 14: 11 matching transactions
# Matching transactions for node 27:
#   - 21: 0 matching transactions
#   - 38: 2 matching transactions
#   - 18: 0 matching transactions
#   - 30: 1 matching transactions
#   - 9: 2 matching transactions
#   - 32: 1 matching transactions
#   - 56: 2 matching transactions
#   - 28: 0 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 4 matching transactions
#   - 53: 3 matching transactions
#   - 52: 0 matching transactions
#   - 57: 4 matching transactions
#   - 0: 1 matching transactions
#   - 15: 4 matching transactions
#   - 2: 6 matching transactions
#   - 43: 6 matching transactions
#   - 5: 0 matching transactions
#   - 36: 3 matching transactions
#   - 44: 6 matching transactions
#   - 29: 5 matching transactions
#   - 17: 5 matching transactions
#   - 47: 4 matching transactions
#   - 49: 6 matching transactions
#   - 7: 3 matching transactions
#   - 45: 5 matching transactions
#   - 13: 2 matching transactions
#   - 37: 1 matching transactions
#   - 41: 6 matching transactions
#   - 51: 6 matching transactions
#   - 24: 4 matching transactions
#   - 59: 1 matching transactions
#   - 22: 5 matching transactions
#   - 26: 1 matching transactions
#   - 50: 5 matching transactions
#   - 1: 6 matching transactions
#   - 16: 1 matching transactions
#   - 8: 6 matching transactions
#   - 34: 6 matching transactions
#   - 3: 4 matching transactions
#   - 23: 6 matching transactions
#   - 39: 2 matching transactions
#   - 20: 6 matching transactions
#   - 55: 5 matching transactions
#   - 6: 0 matching transactions
#   - 54: 6 matching transactions
#   - 14: 6 matching transactions
# Matching transactions for node 45:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 6 matching transactions
#   - 43: 5 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 5 matching transactions
#   - 29: 5 matching transactions
#   - 17: 6 matching transactions
#   - 47: 3 matching transactions
#   - 49: 5 matching transactions
#   - 7: 2 matching transactions
#   - 27: 5 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 6 matching transactions
#   - 51: 6 matching transactions
#   - 24: 5 matching transactions
#   - 59: 0 matching transactions
#   - 22: 5 matching transactions
#   - 26: 2 matching transactions
#   - 50: 4 matching transactions
#   - 1: 6 matching transactions
#   - 16: 2 matching transactions
#   - 8: 5 matching transactions
#   - 34: 6 matching transactions
#   - 3: 5 matching transactions
#   - 23: 6 matching transactions
#   - 39: 3 matching transactions
#   - 20: 6 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 6 matching transactions
#   - 14: 6 matching transactions
# Matching transactions for node 13:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 2 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 3 matching transactions
#   - 33: 3 matching transactions
#   - 48: 3 matching transactions
#   - 53: 1 matching transactions
#   - 52: 1 matching transactions
#   - 57: 3 matching transactions
#   - 0: 2 matching transactions
#   - 15: 3 matching transactions
#   - 2: 3 matching transactions
#   - 43: 2 matching transactions
#   - 5: 1 matching transactions
#   - 36: 2 matching transactions
#   - 44: 2 matching transactions
#   - 29: 2 matching transactions
#   - 17: 3 matching transactions
#   - 47: 1 matching transactions
#   - 49: 2 matching transactions
#   - 7: 0 matching transactions
#   - 27: 2 matching transactions
#   - 45: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 3 matching transactions
#   - 51: 3 matching transactions
#   - 24: 3 matching transactions
#   - 59: 0 matching transactions
#   - 22: 2 matching transactions
#   - 26: 2 matching transactions
#   - 50: 2 matching transactions
#   - 1: 3 matching transactions
#   - 16: 2 matching transactions
#   - 8: 2 matching transactions
#   - 34: 3 matching transactions
#   - 3: 3 matching transactions
#   - 23: 3 matching transactions
#   - 39: 3 matching transactions
#   - 20: 3 matching transactions
#   - 55: 3 matching transactions
#   - 6: 1 matching transactions
#   - 54: 3 matching transactions
#   - 14: 3 matching transactions
# Matching transactions for node 37:
#   - 21: 0 matching transactions
#   - 38: 0 matching transactions
#   - 18: 0 matching transactions
#   - 30: 0 matching transactions
#   - 9: 0 matching transactions
#   - 32: 0 matching transactions
#   - 56: 0 matching transactions
#   - 28: 0 matching transactions
#   - 25: 0 matching transactions
#   - 33: 0 matching transactions
#   - 48: 0 matching transactions
#   - 53: 0 matching transactions
#   - 52: 0 matching transactions
#   - 57: 0 matching transactions
#   - 0: 0 matching transactions
#   - 15: 0 matching transactions
#   - 2: 3 matching transactions
#   - 43: 3 matching transactions
#   - 5: 0 matching transactions
#   - 36: 0 matching transactions
#   - 44: 5 matching transactions
#   - 29: 1 matching transactions
#   - 17: 0 matching transactions
#   - 47: 8 matching transactions
#   - 49: 5 matching transactions
#   - 7: 9 matching transactions
#   - 27: 1 matching transactions
#   - 45: 0 matching transactions
#   - 13: 0 matching transactions
#   - 41: 8 matching transactions
#   - 51: 3 matching transactions
#   - 24: 0 matching transactions
#   - 59: 9 matching transactions
#   - 22: 1 matching transactions
#   - 26: 0 matching transactions
#   - 50: 2 matching transactions
#   - 1: 9 matching transactions
#   - 16: 0 matching transactions
#   - 8: 3 matching transactions
#   - 34: 9 matching transactions
#   - 3: 1 matching transactions
#   - 23: 6 matching transactions
#   - 39: 0 matching transactions
#   - 20: 10 matching transactions
#   - 55: 0 matching transactions
#   - 6: 0 matching transactions
#   - 54: 10 matching transactions
#   - 14: 9 matching transactions
# Matching transactions for node 41:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 9 matching transactions
#   - 43: 8 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 10 matching transactions
#   - 29: 6 matching transactions
#   - 17: 6 matching transactions
#   - 47: 10 matching transactions
#   - 49: 11 matching transactions
#   - 7: 10 matching transactions
#   - 27: 6 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 8 matching transactions
#   - 51: 9 matching transactions
#   - 24: 5 matching transactions
#   - 59: 8 matching transactions
# ...
#   - 8: 1 matching transactions
#   - 34: 2 matching transactions
#   - 3: 2 matching transactions
#   - 23: 2 matching transactions
#   - 39: 2 matching transactions
#   - 20: 2 matching transactions
#   - 55: 2 matching transactions
#   - 6: 1 matching transactions
#   - 54: 2 matching transactions
#   - 14: 2 matching transactions
# Matching transactions for node 8:
#   - 21: 0 matching transactions
#   - 38: 2 matching transactions
#   - 18: 0 matching transactions
#   - 30: 1 matching transactions
#   - 9: 2 matching transactions
#   - 32: 1 matching transactions
#   - 56: 2 matching transactions
#   - 28: 0 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 4 matching transactions
#   - 53: 3 matching transactions
#   - 52: 0 matching transactions
#   - 57: 4 matching transactions
#   - 0: 1 matching transactions
#   - 15: 4 matching transactions
#   - 2: 7 matching transactions
#   - 43: 6 matching transactions
#   - 5: 0 matching transactions
#   - 36: 3 matching transactions
#   - 44: 7 matching transactions
#   - 29: 6 matching transactions
#   - 17: 5 matching transactions
#   - 47: 6 matching transactions
#   - 49: 7 matching transactions
#   - 7: 5 matching transactions
#   - 27: 6 matching transactions
#   - 45: 5 matching transactions
#   - 13: 2 matching transactions
#   - 37: 3 matching transactions
#   - 41: 8 matching transactions
#   - 51: 7 matching transactions
#   - 24: 4 matching transactions
#   - 59: 3 matching transactions
#   - 22: 6 matching transactions
#   - 26: 1 matching transactions
#   - 50: 5 matching transactions
#   - 1: 8 matching transactions
#   - 16: 1 matching transactions
#   - 34: 8 matching transactions
#   - 3: 5 matching transactions
#   - 23: 8 matching transactions
#   - 39: 2 matching transactions
#   - 20: 8 matching transactions
#   - 55: 5 matching transactions
#   - 6: 0 matching transactions
#   - 54: 8 matching transactions
#   - 14: 8 matching transactions
# Matching transactions for node 34:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 9 matching transactions
#   - 43: 8 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 10 matching transactions
#   - 29: 6 matching transactions
#   - 17: 6 matching transactions
#   - 47: 11 matching transactions
#   - 49: 11 matching transactions
#   - 7: 11 matching transactions
#   - 27: 6 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 9 matching transactions
#   - 41: 15 matching transactions
#   - 51: 9 matching transactions
#   - 24: 5 matching transactions
#   - 59: 9 matching transactions
#   - 22: 6 matching transactions
#   - 26: 2 matching transactions
#   - 50: 6 matching transactions
#   - 1: 15 matching transactions
#   - 16: 2 matching transactions
#   - 8: 8 matching transactions
#   - 3: 6 matching transactions
#   - 23: 12 matching transactions
#   - 39: 3 matching transactions
#   - 20: 15 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 16 matching transactions
#   - 14: 16 matching transactions
# Matching transactions for node 3:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 2 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 5 matching transactions
#   - 33: 4 matching transactions
#   - 48: 4 matching transactions
#   - 53: 2 matching transactions
#   - 52: 1 matching transactions
#   - 57: 4 matching transactions
#   - 0: 2 matching transactions
#   - 15: 4 matching transactions
#   - 2: 6 matching transactions
#   - 43: 4 matching transactions
#   - 5: 1 matching transactions
#   - 36: 3 matching transactions
#   - 44: 5 matching transactions
#   - 29: 5 matching transactions
#   - 17: 5 matching transactions
#   - 47: 4 matching transactions
#   - 49: 5 matching transactions
#   - 7: 3 matching transactions
#   - 27: 4 matching transactions
#   - 45: 5 matching transactions
#   - 13: 3 matching transactions
#   - 37: 1 matching transactions
#   - 41: 6 matching transactions
#   - 51: 6 matching transactions
#   - 24: 4 matching transactions
#   - 59: 1 matching transactions
#   - 22: 5 matching transactions
#   - 26: 2 matching transactions
#   - 50: 3 matching transactions
#   - 1: 6 matching transactions
#   - 16: 2 matching transactions
#   - 8: 5 matching transactions
#   - 34: 6 matching transactions
#   - 23: 6 matching transactions
#   - 39: 3 matching transactions
#   - 20: 6 matching transactions
#   - 55: 5 matching transactions
#   - 6: 1 matching transactions
#   - 54: 6 matching transactions
#   - 14: 6 matching transactions
# Matching transactions for node 23:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 9 matching transactions
#   - 43: 8 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 10 matching transactions
#   - 29: 6 matching transactions
#   - 17: 6 matching transactions
#   - 47: 9 matching transactions
#   - 49: 10 matching transactions
#   - 7: 8 matching transactions
#   - 27: 6 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 6 matching transactions
#   - 41: 12 matching transactions
#   - 51: 9 matching transactions
#   - 24: 5 matching transactions
#   - 59: 6 matching transactions
#   - 22: 6 matching transactions
#   - 26: 2 matching transactions
#   - 50: 6 matching transactions
#   - 1: 12 matching transactions
#   - 16: 2 matching transactions
#   - 8: 8 matching transactions
#   - 34: 12 matching transactions
#   - 3: 6 matching transactions
#   - 39: 3 matching transactions
#   - 20: 12 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 12 matching transactions
#   - 14: 12 matching transactions
# Matching transactions for node 39:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 2 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 3 matching transactions
#   - 33: 3 matching transactions
#   - 48: 3 matching transactions
#   - 53: 1 matching transactions
#   - 52: 1 matching transactions
#   - 57: 3 matching transactions
#   - 0: 2 matching transactions
#   - 15: 3 matching transactions
#   - 2: 3 matching transactions
#   - 43: 2 matching transactions
#   - 5: 1 matching transactions
#   - 36: 2 matching transactions
#   - 44: 2 matching transactions
#   - 29: 2 matching transactions
#   - 17: 3 matching transactions
#   - 47: 1 matching transactions
#   - 49: 2 matching transactions
#   - 7: 0 matching transactions
#   - 27: 2 matching transactions
#   - 45: 3 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 3 matching transactions
#   - 51: 3 matching transactions
#   - 24: 3 matching transactions
#   - 59: 0 matching transactions
#   - 22: 2 matching transactions
#   - 26: 2 matching transactions
#   - 50: 2 matching transactions
#   - 1: 3 matching transactions
#   - 16: 2 matching transactions
#   - 8: 2 matching transactions
#   - 34: 3 matching transactions
#   - 3: 3 matching transactions
#   - 23: 3 matching transactions
#   - 20: 3 matching transactions
#   - 55: 3 matching transactions
#   - 6: 1 matching transactions
#   - 54: 3 matching transactions
#   - 14: 3 matching transactions
# Matching transactions for node 20:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 9 matching transactions
#   - 43: 8 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 10 matching transactions
#   - 29: 6 matching transactions
#   - 17: 6 matching transactions
#   - 47: 12 matching transactions
#   - 49: 11 matching transactions
#   - 7: 10 matching transactions
#   - 27: 6 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 10 matching transactions
#   - 41: 14 matching transactions
#   - 51: 9 matching transactions
#   - 24: 5 matching transactions
#   - 59: 9 matching transactions
#   - 22: 6 matching transactions
#   - 26: 2 matching transactions
#   - 50: 6 matching transactions
#   - 1: 16 matching transactions
#   - 16: 2 matching transactions
#   - 8: 8 matching transactions
#   - 34: 15 matching transactions
#   - 3: 6 matching transactions
#   - 23: 12 matching transactions
#   - 39: 3 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 17 matching transactions
#   - 14: 15 matching transactions
# Matching transactions for node 55:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 6 matching transactions
#   - 43: 5 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 5 matching transactions
#   - 29: 5 matching transactions
#   - 17: 6 matching transactions
#   - 47: 3 matching transactions
#   - 49: 5 matching transactions
#   - 7: 2 matching transactions
#   - 27: 5 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 0 matching transactions
#   - 41: 6 matching transactions
#   - 51: 6 matching transactions
#   - 24: 5 matching transactions
#   - 59: 0 matching transactions
#   - 22: 5 matching transactions
#   - 26: 2 matching transactions
#   - 50: 4 matching transactions
#   - 1: 6 matching transactions
#   - 16: 2 matching transactions
#   - 8: 5 matching transactions
#   - 34: 6 matching transactions
#   - 3: 5 matching transactions
#   - 23: 6 matching transactions
#   - 39: 3 matching transactions
#   - 20: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 6 matching transactions
#   - 14: 6 matching transactions
# Matching transactions for node 6:
#   - 21: 1 matching transactions
#   - 38: 1 matching transactions
#   - 18: 1 matching transactions
#   - 30: 1 matching transactions
#   - 9: 1 matching transactions
#   - 32: 1 matching transactions
#   - 56: 1 matching transactions
#   - 28: 1 matching transactions
#   - 25: 1 matching transactions
#   - 33: 1 matching transactions
#   - 48: 1 matching transactions
#   - 53: 0 matching transactions
#   - 52: 1 matching transactions
#   - 57: 1 matching transactions
#   - 0: 1 matching transactions
#   - 15: 1 matching transactions
#   - 2: 1 matching transactions
#   - 43: 0 matching transactions
#   - 5: 1 matching transactions
#   - 36: 1 matching transactions
#   - 44: 0 matching transactions
#   - 29: 0 matching transactions
#   - 17: 1 matching transactions
#   - 47: 0 matching transactions
#   - 49: 0 matching transactions
#   - 7: 0 matching transactions
#   - 27: 0 matching transactions
#   - 45: 1 matching transactions
#   - 13: 1 matching transactions
#   - 37: 0 matching transactions
#   - 41: 1 matching transactions
#   - 51: 1 matching transactions
#   - 24: 1 matching transactions
#   - 59: 0 matching transactions
#   - 22: 0 matching transactions
#   - 26: 1 matching transactions
#   - 50: 0 matching transactions
#   - 1: 1 matching transactions
#   - 16: 1 matching transactions
#   - 8: 0 matching transactions
#   - 34: 1 matching transactions
#   - 3: 1 matching transactions
#   - 23: 1 matching transactions
#   - 39: 1 matching transactions
#   - 20: 1 matching transactions
#   - 55: 1 matching transactions
#   - 54: 1 matching transactions
#   - 14: 1 matching transactions
# Matching transactions for node 54:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 9 matching transactions
#   - 43: 8 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 10 matching transactions
#   - 29: 6 matching transactions
#   - 17: 6 matching transactions
#   - 47: 12 matching transactions
#   - 49: 11 matching transactions
#   - 7: 11 matching transactions
#   - 27: 6 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 10 matching transactions
#   - 41: 15 matching transactions
#   - 51: 9 matching transactions
#   - 24: 5 matching transactions
#   - 59: 10 matching transactions
#   - 22: 6 matching transactions
#   - 26: 2 matching transactions
#   - 50: 6 matching transactions
#   - 1: 18 matching transactions
#   - 16: 2 matching transactions
#   - 8: 8 matching transactions
#   - 34: 16 matching transactions
#   - 3: 6 matching transactions
#   - 23: 12 matching transactions
#   - 39: 3 matching transactions
#   - 20: 17 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 14: 16 matching transactions
# Matching transactions for node 14:
#   - 21: 1 matching transactions
#   - 38: 3 matching transactions
#   - 18: 1 matching transactions
#   - 30: 2 matching transactions
#   - 9: 3 matching transactions
#   - 32: 2 matching transactions
#   - 56: 3 matching transactions
#   - 28: 1 matching transactions
#   - 25: 6 matching transactions
#   - 33: 5 matching transactions
#   - 48: 5 matching transactions
#   - 53: 3 matching transactions
#   - 52: 1 matching transactions
#   - 57: 5 matching transactions
#   - 0: 2 matching transactions
#   - 15: 5 matching transactions
#   - 2: 9 matching transactions
#   - 43: 8 matching transactions
#   - 5: 1 matching transactions
#   - 36: 4 matching transactions
#   - 44: 10 matching transactions
#   - 29: 6 matching transactions
#   - 17: 6 matching transactions
#   - 47: 11 matching transactions
#   - 49: 11 matching transactions
#   - 7: 11 matching transactions
#   - 27: 6 matching transactions
#   - 45: 6 matching transactions
#   - 13: 3 matching transactions
#   - 37: 9 matching transactions
#   - 41: 15 matching transactions
#   - 51: 9 matching transactions
#   - 24: 5 matching transactions
#   - 59: 9 matching transactions
#   - 22: 6 matching transactions
#   - 26: 2 matching transactions
#   - 50: 6 matching transactions
#   - 1: 15 matching transactions
#   - 16: 2 matching transactions
#   - 8: 8 matching transactions
#   - 34: 16 matching transactions
#   - 3: 6 matching transactions
#   - 23: 12 matching transactions
#   - 39: 3 matching transactions
#   - 20: 15 matching transactions
#   - 55: 6 matching transactions
#   - 6: 1 matching transactions
#   - 54: 16 matching transactions

# %% [markdown]
# ## GIVEN MATCHING TRANSACTIONS, NOW FURTHER ANALYSIS USING QUORUM SETS AND THRESHOLD

# %% [markdown]
# QUORUM SETS AND THRESHOLD USED IN SIMULATOR FOR ROUND OF LUNHC

# %%
quorum_sets = {
                    "Alice": ["Bob", "Carol", "Dave"],
                    "Bob": ["Alice", "Carol", "Dave"],
                    "Carol": ["Alice", "Bob", "Dave"],
                    "Dave": ["Alice", "Bob", "Carol"],
                    "Elsie": ["Alice", "Bob", "Carol", "Dave"],
                    "Fred": ["Alice", "Bob", "Carol", "Dave"],
                    "Gwen": ["Alice", "Bob", "Carol", "Dave"],
                    "Hank": ["Alice", "Bob", "Carol", "Dave"],
                    "Inez": ["Elsie", "Fred", "Gwen", "Hank"],
                    "John": ["Elsie", "Fred", "Gwen", "Hank"]
}

quorum_thresholds = {
                    "Alice": 2, "Bob": 2, "Carol": 2, "Dave": 2,  # 2 out of 3 → 67%
                    "Elsie": 2, "Fred": 2, "Gwen": 2, "Hank": 2,  # 2 out of 4 → 50%
                    "Inez": 2, "John": 2  # 2 out of 4 → 50%
}
top_tier_nodes = ["Alice", "Bob", "Carol", "Dave"] # each depends on two of its neighbors for a quorum
middle_tier_nodes = ["Elsie", "Fred", "Gwen", "Hank"] # each depends on any two members of the top tier
bottom_tier_nodes = ["Inez", "John"] # each depends on any two members of the middle tier.

# %%
def compute_matching_transactions_by_tiers(df, quorum_sets, quorum_thresholds, top_tier_nodes, middle_tier_nodes, bottom_tier_nodes):
    matching_counts = {}

    # Iterate over the nodes in the DataFrame
    for i, row_i in df.iterrows():
        node_i = row_i["node name"]
        transactions_i = row_i["Finalised transactions"]

        matching_transactions = {
            "total": len(transactions_i),  # Total transactions for node_i
            "top_tier": {},
            "middle_tier": {},
            "bottom_tier": {}
        }

        # Compare node_i's transactions with others in their respective tiers
        for j, row_j in df.iterrows():
            if i != j:  # Don't compare the node with itself
                node_j = row_j["node name"]
                transactions_j = row_j["Finalised transactions"]

                # Find common transactions between node_i and node_j
                common_transactions = transactions_i.intersection(transactions_j)
                match_count = len(common_transactions)

                # Determine the tier for node_j based on its position in the quorum_sets
                if node_j in quorum_sets[node_i]:
                    if node_j in top_tier_nodes:
                        matching_transactions["top_tier"][node_j] = match_count
                    elif node_j in middle_tier_nodes:
                        matching_transactions["middle_tier"][node_j] = match_count
                    elif node_j in bottom_tier_nodes:
                        matching_transactions["bottom_tier"][node_j] = match_count

        matching_counts[node_i] = matching_transactions

    return matching_counts

# %%
matching_counts = compute_matching_transactions_by_tiers(df, quorum_sets, quorum_thresholds, top_tier_nodes, middle_tier_nodes, bottom_tier_nodes)

# Display the results
for node, matches in matching_counts.items():
    if node in top_tier_nodes:
        tier = "Top-tier"
    elif node in middle_tier_nodes:
        tier = "Middle-tier"
    elif node in bottom_tier_nodes:
        tier = "Bottom-tier"
    else:
        tier = "Unknown-tier"
    # Print the node, its tier, and total transactions before showing matches
    print(f"Matching transactions for node {node} in tier {tier}(Total: {matches['total']} transactions):")
    
    print(f"  - Top-tier matches:")
    for top_node, count in matches["top_tier"].items():
        print(f"    * {top_node}: {count} matching transactions")
    
    print(f"  - Middle-tier matches:")
    for middle_node, count in matches["middle_tier"].items():
        print(f"    * {middle_node}: {count} matching transactions")
    
    print(f"  - Bottom-tier matches:")
    for bottom_node, count in matches["bottom_tier"].items():
        print(f"    * {bottom_node}: {count} matching transactions")
    
    print()  # For readability between node results
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 matching_counts = compute_matching_transactions_by_tiers(df, quorum_sets, quorum_thresholds, top_tier_nodes, middle_tier_nodes, bottom_tier_nodes)
#       3 # Display the results
#       4 for node, matches in matching_counts.items():
#
# Cell In[259], line 27, in compute_matching_transactions_by_tiers(df, quorum_sets, quorum_thresholds, top_tier_nodes, middle_tier_nodes, bottom_tier_nodes)
#      24 match_count = len(common_transactions)
#      26 # Determine the tier for node_j based on its position in the quorum_sets
# ---> 27 if node_j in quorum_sets[node_i]:
#      28     if node_j in top_tier_nodes:
#      29         matching_transactions["top_tier"][node_j] = match_count
#
# KeyError: '21'

# %% [markdown]
# ### DELAYS IN EXTERNALISATION FOR LEAD NODES VS OUTER NODES

# %%
import pandas as pd

def analyze_finalization_delay(df, top_tier, middle_tier, bottom_tier):
    """
    Analyzes the delay in finalization times across the three-tier structure.

    Args:
        df (pd.DataFrame): The DataFrame containing node names and finalization timestamps.
        top_tier (list): List of top-tier node names.
        middle_tier (list): List of middle-tier node names.
        bottom_tier (list): List of bottom-tier node names.

    Returns:
        dict: Contains average finalization times for each tier and delays between them.
    """
    top_times = df[df["node name"].isin(top_tier)]["Timestamp of finalisation"]
    middle_times = df[df["node name"].isin(middle_tier)]["Timestamp of finalisation"]
    bottom_times = df[df["node name"].isin(bottom_tier)]["Timestamp of finalisation"]

    top_avg = top_times.mean()
    middle_avg = middle_times.mean()
    bottom_avg = bottom_times.mean()

    delay_top_to_middle = middle_avg - top_avg
    delay_middle_to_bottom = bottom_avg - middle_avg
    delay_top_to_bottom = bottom_avg - top_avg

    return {
        "top_avg_finalization_time": top_avg,
        "middle_avg_finalization_time": middle_avg,
        "bottom_avg_finalization_time": bottom_avg,
        "delay_top_to_middle": delay_top_to_middle,
        "delay_middle_to_bottom": delay_middle_to_bottom,
        "delay_top_to_bottom": delay_top_to_bottom
    }

# %%
# Define groups
top_tier = ["Alice", "Bob", "Carol", "Dave"] # each depends on two of its neighbors for a quorum
middle_tier = ["Elsie", "Fred", "Gwen", "Hank"] # each depends on any two members of the top tier
bottom_tier = ["Inez", "John"] # each depends on any two members of the middle tier.

# Run analyses
finalization_delay = analyze_finalization_delay(df, top_tier, middle_tier, bottom_tier)

# Print results
print("Finalization Delay Analysis:", finalization_delay)

# %% [markdown]
# ### TRANSACTION PROPAGATION IN NODES WITH NO LINKS (OR WEAK LINKS THROUGH PEERS)

# %%
from itertools import combinations
import pandas as pd

def transaction_overlap(df, group1, group2, group3):
    """
    Measures the percentage of matching transactions between three groups of nodes.
    Computes overlap separately for (g1-g2), (g1-g3), (g2-g3), and all three together.

    Args:
        df (pd.DataFrame): The DataFrame containing nodes and finalized transactions.
        group1 (list): First group of nodes (e.g., top tier).
        group2 (list): Second group of nodes (e.g., middle tier).
        group3 (list): Third group of nodes (e.g., bottom tier).

    Returns:
        dict: Contains average transaction match percentages for each pair of groups
              and overall across all three groups.
    """
    def compute_overlap(nodes1, nodes2):
        """Helper function to compute overlap between two sets of nodes."""
        total_pairs = 0
        total_match_percentage = 0

        for (node1, txs1), (node2, txs2) in combinations(
            zip(df["node name"], df["Finalised transactions"]), 2
        ):
             # cjecl that one noed is in group 'nodes1' and the other is in 'nodes2', not that they are part of the same group
            if node1 in nodes1 and node2 in nodes2:
                total_pairs += 1
                match_count = len(set(txs1).intersection(set(txs2))) # compare each matching transaction
                total_transactions = len(set(txs1).union(set(txs2))) # total transactions in both externalised values
                match_percentage = (match_count / total_transactions) if total_transactions else 0
                total_match_percentage += match_percentage

        return total_match_percentage / total_pairs if total_pairs else 0

    # Compute pairwise overlaps
    g1_g2_overlap = compute_overlap(group1, group2)
    g1_g3_overlap = compute_overlap(group1, group3)
    g2_g3_overlap = compute_overlap(group2, group3)

    # Compute overall overlap across all three groups
    all_groups_overlap = compute_overlap(group1 + group2, group3)

    return {
        "Top-Middle Overlap": g1_g2_overlap,
        "Top-Bottom Overlap": g1_g3_overlap,
        "Middle-Bottom Overlap": g2_g3_overlap,
        "Overall Three-Group Overlap": all_groups_overlap
    }

# %%
propagation_analysis = transaction_overlap(df, top_tier, middle_tier, bottom_tier)
print("Transaction Propagation Analysis:", propagation_analysis)

# %% [markdown]
# ### EFFECT OF LOWER QUORUM THRESHOLD

# %%
def analyze_threshold_effect(df, quorum_thresholds):
    """
    Analyzes how different quorum thresholds affect transaction agreement.

    Args:
        df (pd.DataFrame): The DataFrame containing nodes and finalized transactions.
        quorum_thresholds (dict): A dictionary mapping nodes to their quorum thresholds.

    Returns:
        dict: Contains statistics on transaction agreement and threshold impact.
    """
    unique_transactions_per_node = df["Finalised transactions"].apply(len)
    avg_transactions = unique_transactions_per_node.mean()
    
    threshold_agreement = {
        node: {
            "threshold": quorum_thresholds[node],
            "transactions_finalized": df[df["node name"] == node]["No. of finalised transactions"].values[0]
        }
        for node in quorum_thresholds
    }
    threshold_df = pd.DataFrame(threshold_agreement)

    return  avg_transactions, threshold_df

# %%
avg_txs, threshold_df = analyze_threshold_effect(df, quorum_thresholds)
print("Threshold Effect Analysis:")
print("Average_transactions_finalized", avg_txs)
display(threshold_df)

# %% [markdown]
# # CONCLUSIONS FROM DATA ANALYSIS

# %% [markdown]
# Finalization Delays:
#
# The Top tier finalized transactions the earliest on average, but the delay between Top-Middle and Middle-Bottom is relatively small.
# Delay between Top and Bottom being negative (-7.7) suggests that nodes in the Top tier finalize faster than those in the Bottom tier.
# The asynchronous behavior of the simulator means there is no global synchronization of node actions, which likely results in these delays. Synchronization points during the real SCP implementation are crucial to maintain consistency across nodes at different tiers, but the simulator misses this aspect.

# %% [markdown]
# Transaction Overlap:
#
# The low transaction overlap indicates that transactions are not propagated efficiently between the tiers. In a real-world SCP implementation, once a value is finalized in one tier, it should propagate to the other tiers effectively to ensure a quicker consensus process. The simulator’s lack of synchronization likely hinders this propagation.

# %% [markdown]
# Effect of Quorum Thresholds:
#
# The large variation in finalized transactions (1 to 61) indicates that quorum thresholds are having inconsistent effects across nodes. Some nodes seem to finalize transactions quicker than others, but overall, the average finalized transactions (26) indicate some nodes are not able to meet the quorum efficiently, possibly because lower thresholds result in early externalization without proper coordination
